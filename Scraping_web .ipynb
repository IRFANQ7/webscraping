# %%
#import library
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#import website link

# %%
base_url = 'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-2020'

# %%
r = requests.get(base_url)

# %%
soup=BeautifulSoup(r.content, 'html.parser')

# %%
#extract 1-object 2-Publication_Date 3-Bidding_Date 4-link

# %%
object = soup.find_all('p')[0].get_text()

# %%
object
# Out:
# 'Registro de Preços pelo prazo de 12 meses, para aquisição de grampo galvanizado.'

# %%
info=soup.findAll(attrs = {'class': 'lbl-licitacao'})

# %%
info
# Out:
# [<span class="col-sm-6 lbl-licitacao"><span>DATA DA PUBLICAÇÃO: </span>02/02/2021</span>,
#  <span class="lbl-licitacao"><span>OBJETO:</span></span>,
#  <span class="lbl-licitacao"><span>INFORMAÇÕES COMPLEMENTARES:</span></span>,
#  <span class="col-sm-6 lbl-licitacao"><span>MODALIDADE: </span>Pregão Eletrônico</span>,
#  <span class="col-sm-6 lbl-licitacao"><span>SITUAÇÃO: </span>Homologado</span>,
#  <span class="col-sm-6 lbl-licitacao"><span>DATA DA LICITAÇÃO: </span>18/02/2021</span>,
#  <span class="lbl-licitacao"><span>HISTÓRICO:</span></span>]

# %%
Publication_Date = info[0].text.replace('DATA DA PUBLICAÇÃO:'," ")

# %%
Bidding_Date = info[5].text.replace('DATA DA LICITAÇÃO:'," ")

# %%
url_list = ["{}{}".format(base_url, str(page)) for page in range(1, 408)]
s=[]
for url in url_list:
    print (url)
    s.append(url)
# Out:
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20201
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20202
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20203
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20204
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20205
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20206
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20207
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20208
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20209
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-202010
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-202011
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-202012
# https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-202013
# ...

# %%
data = [[object,Publication_Date,Bidding_Date,url_list]]

# %%
data
# Out:
# [['Registro de Preços pelo prazo de 12 meses, para aquisição de grampo galvanizado.',
#   '  02/02/2021',
#   '  18/02/2021',
#   ['https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20201',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20202',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20203',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20204',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20205',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20206',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20207',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20208',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-20209',
#    'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-202010',
# ...

# %%
#convert into dataframe

# %%
df = pd.DataFrame(data, columns = ['object','Publication_Date','Bidding_Date','url_list'])

# %%
df
# Out:
#                                               object Publication_Date  \
# 0  Registro de Preços pelo prazo de 12 meses, par...       02/02/2021
#
#    Bidding_Date                                           url_list
# 0    18/02/2021  [https://prefeitura.pbh.gov.br/saude/licitacao...

# %%
#save dataframe into csv file

# %%
df.to_csv('data07.csv')

# %%
df.to_csv('data07.')

# %%
for i in range (1,10):
    base_url = 'https://prefeitura.pbh.gov.br/saude/licitacao/pregao-eletronico-151-2020/+str(i)'
    r = requests.get(base_url)
    if(r.status_code==200):
        print('data fetched successfully', i)
        soup=BeautifulSoup(r.content, 'html.parser')
        object = soup.find_all('p')[0].get_text()
        Publication_Date = info[0].text.replace('DATA DA PUBLICAÇÃO:'," ")
        Bidding_Date = info[5].text.replace('DATA DA LICITAÇÃO:'," ")
        data1.insert(data,[object,Publication_Date,Bidding_Date,url_list])
    else:
        print('data not found ',i)
df = pd.DataFrame(data, columns = ['object','Publication_Date','Bidding_Date','url_list'])  
df.to_csv('assignment.csv')
# Out:
# data not found  1
# data not found  2
# data not found  3
# data not found  4
# data not found  5
# data not found  6
# data not found  7
# data not found  8
# data not found  9
